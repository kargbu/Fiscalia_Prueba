# %% [markdown]
# <a href="https://colab.research.google.com/github/kargbu/Fiscalia_Prueba/blob/main/Prueba_t%C3%A9cnica_Karina_Buend%C3%ADa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Prueba técnica**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Hola, esta es la prueba técnica para verirficar los conocimientos que tienes en análisis y visualización de datos. El objetivo es crear visualizaciones que sean fáciles de comprender para la gente que toma decisiones en materia de procuracion de justicia. Para este tipo de gente es importante saber el dato exacto, por lo que las etiquetas y leyendas deben de ser muy claras.

# %% [markdown]
# Trabajamos principalmente con dos bases de datos: una de carpetas de investigación y otra de víctimas. Cada carpeta está relacionada con un delito, fecha y lugar. La base de víctimas incluye cuántas víctimas estuvieron involucradas en la carpeta. De la base de carpetas, debes saber que no existen carpetas repetidas, ya que puede haber más de una víctima en una carpeta, y que en cada carpeta debe de haber al menos una víctima.
#
# Cuando pedimos algo por fecha (puede ser año o mes) siempre usamos la fecha de inicio, a menos que explícitamente digamos que necesitamos algo por fecha de hechos.
#
# Puedes elegir los estilos que quieras mientras que se muestre lo que se pide. Se tendrá en cuenta la eficiencia de código y su limpieza.

# %%
import pandas as pd

# %%
#base de carpetas
data_inc = pd.read_csv("data_inc.csv")
print(data_inc.info)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8aace1e7e3e8> in <cell line: 0>()
#       1 #base de carpetas
# ----> 2 data_inc = pd.read_csv("an_data_inc.csv")
#       3 print(data_inc.info)
#
# ...

# %% [markdown]
# ###Visualización de datos

# %% [markdown]
# 1- Haz una gráfica de columnas de la cantidad de carpetas por año

# %% [markdown]
# 2- Supon que es 18 de julio de 2023, Haz una gráfica de columnas de la cantidad de víctimas por homicidio doloso (considerando feminicidio) usando el corte de 18 de julio para cada año. El objetivo de esta visualización es comparar los años y ver cuál es el que ha tenido más víctimas

# %% [markdown]
# 3- Haz gráfico de las 16 alcaldías con su tendencia mensual. Se necesita 16 gráficos (uno por cada alcadía) estilo facet.Te ponemos un ejemplo de lo que buscamos ![grafica_facet.png](data:image/png;base64,...)

# %% [markdown]
# ## **Analisis de datos**
